# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
tp= purchase_data.nunique()['SN']
tp
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
item_val = purchase_data["Item ID"]
items = len(item_val.unique())

price_ave = round((purchase_data["Price"]).mean(),2)


purchase_total = (purchase_data["Purchase ID"]).count()
total_revenue = (purchase_data["Price"]).sum()


purchasing_analysis = pd.DataFrame({"Number of Unique Items":[items],
                           "Average Price": [price_ave], 
                           "Number of Purchases": [purchase_total], 
                           "Total Revenue": [total_revenue]})

purchasing_analysis.style.format({'Average Price':"${:}",
                         'Total Revenue': '${:}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_e3ddc7c8_c2d7_11e9_b232_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e3ddc7c8_c2d7_11e9_b232_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e3ddc7c8_c2d7_11e9_b232_acde48001122row0_col0" class="data row0 col0" >183</td>
#                         <td id="T_e3ddc7c8_c2d7_11e9_b232_acde48001122row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_e3ddc7c8_c2d7_11e9_b232_acde48001122row0_col2" class="data row0 col2" >780</td>
#                         <td id="T_e3ddc7c8_c2d7_11e9_b232_acde48001122row0_col3" class="data row0 col3" >$2379.77</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#male/female %
gender_data = purchase_data.groupby("Gender")

gender_data_count = gender_data.nunique()["SN"]

#other/non-disclosed
player_data_percent = gender_data_count / tp * 100

gender_df = pd.DataFrame({"Total Count": gender_data_count,"Percentage of Players": player_data_percent})

gender_df = gender_df.sort_values(["Total Count"], ascending = False)
gender_df.style.format({"Percentage of Players":"{:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_222faf64_c2d8_11e9_b232_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_222faf64_c2d8_11e9_b232_acde48001122level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_222faf64_c2d8_11e9_b232_acde48001122row0_col0" class="data row0 col0" >484</td>
#                         <td id="T_222faf64_c2d8_11e9_b232_acde48001122row0_col1" class="data row0 col1" >84.03</td>
#             </tr>
#             <tr>
#                         <th id="T_222faf64_c2d8_11e9_b232_acde48001122level0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_222faf64_c2d8_11e9_b232_acde48001122row1_col0" class="data row1 col0" >81</td>
#                         <td id="T_222faf64_c2d8_11e9_b232_acde48001122row1_col1" class="data row1 col1" >14.06</td>
#             </tr>
#             <tr>
#                         <th id="T_222faf64_c2d8_11e9_b232_acde48001122level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_222faf64_c2d8_11e9_b232_acde48001122row2_col0" class="data row2 col0" >11</td>
#                         <td id="T_222faf64_c2d8_11e9_b232_acde48001122row2_col1" class="data row2 col1" >1.91</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_count = purchase_data.groupby("Gender")["Purchase ID"].count()

price_avg = purchase_data.groupby("Gender")["Price"].mean()

purchase_avg_price = purchase_data.groupby("Gender")["Price"].sum()

avg_purchase_person = purchase_avg_price/gender_data_count

# Display Dataframe
gender_df = pd.DataFrame({"Purchase Count": purchase_count, 
                                    "Average Purchase Price": price_avg,
                                    "Average Purchase Value":purchase_avg_price,
                                    "Avg Purchase Total per Person": avg_purchase_person})



gender_df.style.format({"Average Purchase Value":"${:,.2f}",
                                  "Average Purchase Price":"${:,.2f}",
                                  "Avg Purchase Total per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_7a421e8a_c2d8_11e9_b232_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Average Purchase Value</th>        <th class="col_heading level0 col3" >Avg Purchase Total per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a421e8a_c2d8_11e9_b232_acde48001122level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row0_col0" class="data row0 col0" >113</td>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row0_col1" class="data row0 col1" >$3.20</td>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row0_col2" class="data row0 col2" >$361.94</td>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row0_col3" class="data row0 col3" >$4.47</td>
#             </tr>
#             <tr>
#                         <th id="T_7a421e8a_c2d8_11e9_b232_acde48001122level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row1_col0" class="data row1 col0" >652</td>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row1_col1" class="data row1 col1" >$3.02</td>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row1_col2" class="data row1 col2" >$1,967.64</td>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row1_col3" class="data row1 col3" >$4.07</td>
#             </tr>
#             <tr>
#                         <th id="T_7a421e8a_c2d8_11e9_b232_acde48001122level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row2_col1" class="data row2 col1" >$3.35</td>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row2_col2" class="data row2 col2" >$50.19</td>
#                         <td id="T_7a421e8a_c2d8_11e9_b232_acde48001122row2_col3" class="data row2 col3" >$4.56</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
bins = [0, 9, 14, 19, 24, 29, 34, 39, 100]

purchase_data["Age Group"] = pd.cut(purchase_data["Age"],bins, labels=labels)
purchase_data

age_group = purchase_data.groupby("Age Group")

total_age = age_group["SN"].nunique()

total_by_age = (total_age/tp) * 100

age_df = pd.DataFrame({"Total Count": total_age,"Percentage of Players": total_by_age, })


age_df.style.format({"Percentage of Players":"{:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_97d37c96_c2d8_11e9_b232_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_97d37c96_c2d8_11e9_b232_acde48001122level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row0_col1" class="data row0 col1" >2.95</td>
#             </tr>
#             <tr>
#                         <th id="T_97d37c96_c2d8_11e9_b232_acde48001122level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row1_col0" class="data row1 col0" >22</td>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row1_col1" class="data row1 col1" >3.82</td>
#             </tr>
#             <tr>
#                         <th id="T_97d37c96_c2d8_11e9_b232_acde48001122level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row2_col0" class="data row2 col0" >107</td>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row2_col1" class="data row2 col1" >18.58</td>
#             </tr>
#             <tr>
#                         <th id="T_97d37c96_c2d8_11e9_b232_acde48001122level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row3_col0" class="data row3 col0" >258</td>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row3_col1" class="data row3 col1" >44.79</td>
#             </tr>
#             <tr>
#                         <th id="T_97d37c96_c2d8_11e9_b232_acde48001122level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row4_col0" class="data row4 col0" >77</td>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row4_col1" class="data row4 col1" >13.37</td>
#             </tr>
#             <tr>
#                         <th id="T_97d37c96_c2d8_11e9_b232_acde48001122level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row5_col0" class="data row5 col0" >52</td>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row5_col1" class="data row5 col1" >9.03</td>
#             </tr>
#             <tr>
#                         <th id="T_97d37c96_c2d8_11e9_b232_acde48001122level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row6_col0" class="data row6 col0" >31</td>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row6_col1" class="data row6 col1" >5.38</td>
#             </tr>
#             <tr>
#                         <th id="T_97d37c96_c2d8_11e9_b232_acde48001122level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row7_col0" class="data row7 col0" >12</td>
#                         <td id="T_97d37c96_c2d8_11e9_b232_acde48001122row7_col1" class="data row7 col1" >2.08</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_price_avg = age_group["Price"].mean()
total_purchase = age_group["Price"].sum()
purchase_by_age = age_group["Purchase ID"].count()

purchase_per_person_avg = total_purchase/total_age

analysis_df = pd.DataFrame({"Purchase Count": purchase_by_age,
                                 "Average Purchase Price": purchase_price_avg,
                                 "Total Purchase Value":total_purchase,
                                 "Average Purchase Total per Person": purchase_per_person_avg})

analysis_df.style.format({"Average Purchase Price":"${:,.2f}",
                               "Total Purchase Value":"${:,.2f}",
                               "Average Purchase Total per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_d3a6787c_c2d8_11e9_b232_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Average Purchase Total per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d3a6787c_c2d8_11e9_b232_acde48001122level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_d3a6787c_c2d8_11e9_b232_acde48001122level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row1_col0" class="data row1 col0" >28</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_d3a6787c_c2d8_11e9_b232_acde48001122level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row2_col0" class="data row2 col0" >136</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_d3a6787c_c2d8_11e9_b232_acde48001122level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row3_col0" class="data row3 col0" >365</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row3_col2" class="data row3 col2" >$1,114.06</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_d3a6787c_c2d8_11e9_b232_acde48001122level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row4_col0" class="data row4 col0" >101</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_d3a6787c_c2d8_11e9_b232_acde48001122level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row5_col0" class="data row5 col0" >73</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_d3a6787c_c2d8_11e9_b232_acde48001122level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row6_col0" class="data row6 col0" >41</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_d3a6787c_c2d8_11e9_b232_acde48001122level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row7_col0" class="data row7 col0" >13</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_d3a6787c_c2d8_11e9_b232_acde48001122row7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
purchase_spender = purchase_data.groupby("SN")["Purchase ID"].count()
avg_price_spender = purchase_data.groupby("SN")["Price"].mean()
total_spender = purchase_data.groupby("SN")["Price"].sum()

top_spenders_df = pd.DataFrame({"Purchase Count": purchase_spender,
                             "Average Purchase Price": avg_price_spender,
                             "Total Purchase Value":total_spender})

top_spenders_desc_df = top_spenders_df.sort_values(["Total Purchase Value"], ascending=False).head()

top_spenders_desc_df.style.format({"Average Purchase Total":"${:,.2f}",
                                 "Average Purchase Price":"${:,.2f}", 
                                 "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_eac74874_c2d8_11e9_b232_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eac74874_c2d8_11e9_b232_acde48001122level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row0_col1" class="data row0 col1" >$3.79</td>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row0_col2" class="data row0 col2" >$18.96</td>
#             </tr>
#             <tr>
#                         <th id="T_eac74874_c2d8_11e9_b232_acde48001122level0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row1_col1" class="data row1 col1" >$3.86</td>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row1_col2" class="data row1 col2" >$15.45</td>
#             </tr>
#             <tr>
#                         <th id="T_eac74874_c2d8_11e9_b232_acde48001122level0_row2" class="row_heading level0 row2" >Chamjask73</th>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row2_col1" class="data row2 col1" >$4.61</td>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row2_col2" class="data row2 col2" >$13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_eac74874_c2d8_11e9_b232_acde48001122level0_row3" class="row_heading level0 row3" >Iral74</th>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row3_col1" class="data row3 col1" >$3.40</td>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row3_col2" class="data row3 col2" >$13.62</td>
#             </tr>
#             <tr>
#                         <th id="T_eac74874_c2d8_11e9_b232_acde48001122level0_row4" class="row_heading level0 row4" >Iskadarya95</th>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row4_col1" class="data row4 col1" >$4.37</td>
#                         <td id="T_eac74874_c2d8_11e9_b232_acde48001122row4_col2" class="data row4 col2" >$13.10</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
items_df = purchase_data[["Item ID", "Item Name", "Price"]]

item_group = items_df.groupby(["Item ID","Item Name"])

values_df = pd.DataFrame({"Purchase Count": item_group["Price"].count(), 
#                                    "Item Price": purchase_val/item_group["Price"].count(),
                                   "Total Purchase Value":(item_group["Price"].sum())})

values_desc_df = values_df.sort_values(["Purchase Count"], ascending=False).head()


values_desc_df.style.format({"Item Price":"${:,.2f}",
                                "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_80bb9226_c2da_11e9_b232_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80bb9226_c2da_11e9_b232_acde48001122level0_row0" class="row_heading level0 row0" >178</th>
#                         <th id="T_80bb9226_c2da_11e9_b232_acde48001122level1_row0" class="row_heading level1 row0" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_80bb9226_c2da_11e9_b232_acde48001122row0_col0" class="data row0 col0" >12</td>
#                         <td id="T_80bb9226_c2da_11e9_b232_acde48001122row0_col1" class="data row0 col1" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_80bb9226_c2da_11e9_b232_acde48001122level0_row1" class="row_heading level0 row1" >145</th>
#                         <th id="T_80bb9226_c2da_11e9_b232_acde48001122level1_row1" class="row_heading level1 row1" >Fiery Glass Crusader</th>
#                         <td id="T_80bb9226_c2da_11e9_b232_acde48001122row1_col0" class="data row1 col0" >9</td>
#                         <td id="T_80bb9226_c2da_11e9_b232_acde48001122row1_col1" class="data row1 col1" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_80bb9226_c2da_11e9_b232_acde48001122level0_row2" class="row_heading level0 row2" >108</th>
#                         <th id="T_80bb9226_c2da_11e9_b232_acde48001122level1_row2" class="row_heading level1 row2" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_80bb9226_c2da_11e9_b232_acde48001122row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_80bb9226_c2da_11e9_b232_acde48001122row2_col1" class="data row2 col1" >$31.77</td>
#             </tr>
#             <tr>
#                         <th id="T_80bb9226_c2da_11e9_b232_acde48001122level0_row3" class="row_heading level0 row3" >82</th>
#                         <th id="T_80bb9226_c2da_11e9_b232_acde48001122level1_row3" class="row_heading level1 row3" >Nirvana</th>
#                         <td id="T_80bb9226_c2da_11e9_b232_acde48001122row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_80bb9226_c2da_11e9_b232_acde48001122row3_col1" class="data row3 col1" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_80bb9226_c2da_11e9_b232_acde48001122level0_row4" class="row_heading level0 row4" >19</th>
#                         <th id="T_80bb9226_c2da_11e9_b232_acde48001122level1_row4" class="row_heading level1 row4" >Pursuit, Cudgel of Necromancy</th>
#                         <td id="T_80bb9226_c2da_11e9_b232_acde48001122row4_col0" class="data row4 col0" >8</td>
#                         <td id="T_80bb9226_c2da_11e9_b232_acde48001122row4_col1" class="data row4 col1" >$8.16</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Most Profitable Items

# %%
# Out:
# <style  type="text/css" >
# </style><table id="T_897e669a_c2da_11e9_b232_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_897e669a_c2da_11e9_b232_acde48001122level0_row0" class="row_heading level0 row0" >178</th>
#                         <th id="T_897e669a_c2da_11e9_b232_acde48001122level1_row0" class="row_heading level1 row0" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_897e669a_c2da_11e9_b232_acde48001122row0_col0" class="data row0 col0" >12</td>
#                         <td id="T_897e669a_c2da_11e9_b232_acde48001122row0_col1" class="data row0 col1" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_897e669a_c2da_11e9_b232_acde48001122level0_row1" class="row_heading level0 row1" >145</th>
#                         <th id="T_897e669a_c2da_11e9_b232_acde48001122level1_row1" class="row_heading level1 row1" >Fiery Glass Crusader</th>
#                         <td id="T_897e669a_c2da_11e9_b232_acde48001122row1_col0" class="data row1 col0" >9</td>
#                         <td id="T_897e669a_c2da_11e9_b232_acde48001122row1_col1" class="data row1 col1" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_897e669a_c2da_11e9_b232_acde48001122level0_row2" class="row_heading level0 row2" >108</th>
#                         <th id="T_897e669a_c2da_11e9_b232_acde48001122level1_row2" class="row_heading level1 row2" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_897e669a_c2da_11e9_b232_acde48001122row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_897e669a_c2da_11e9_b232_acde48001122row2_col1" class="data row2 col1" >$31.77</td>
#             </tr>
#             <tr>
#                         <th id="T_897e669a_c2da_11e9_b232_acde48001122level0_row3" class="row_heading level0 row3" >82</th>
#                         <th id="T_897e669a_c2da_11e9_b232_acde48001122level1_row3" class="row_heading level1 row3" >Nirvana</th>
#                         <td id="T_897e669a_c2da_11e9_b232_acde48001122row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_897e669a_c2da_11e9_b232_acde48001122row3_col1" class="data row3 col1" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_897e669a_c2da_11e9_b232_acde48001122level0_row4" class="row_heading level0 row4" >19</th>
#                         <th id="T_897e669a_c2da_11e9_b232_acde48001122level1_row4" class="row_heading level1 row4" >Pursuit, Cudgel of Necromancy</th>
#                         <td id="T_897e669a_c2da_11e9_b232_acde48001122row4_col0" class="data row4 col0" >8</td>
#                         <td id="T_897e669a_c2da_11e9_b232_acde48001122row4_col1" class="data row4 col1" >$8.16</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
values_val_desc_df = values_df.sort_values(["Total Purchase Value"],
                                                   ascending=False)
values_val_desc_df .style.format({"Item Price":"${:,.2f}",
                                "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_c191e8fe_c2da_11e9_b232_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row0" class="row_heading level0 row0" >178</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row0" class="row_heading level1 row0" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row0_col0" class="data row0 col0" >12</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row0_col1" class="data row0 col1" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row1" class="row_heading level0 row1" >82</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row1" class="row_heading level1 row1" >Nirvana</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row1_col0" class="data row1 col0" >9</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row1_col1" class="data row1 col1" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row2" class="row_heading level0 row2" >145</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row2" class="row_heading level1 row2" >Fiery Glass Crusader</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row2_col1" class="data row2 col1" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row3" class="row_heading level0 row3" >92</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row3" class="row_heading level1 row3" >Final Critic</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row3_col0" class="data row3 col0" >8</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row3_col1" class="data row3 col1" >$39.04</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row4" class="row_heading level0 row4" >103</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row4_col0" class="data row4 col0" >8</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row4_col1" class="data row4 col1" >$34.80</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row5" class="row_heading level0 row5" >59</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row5" class="row_heading level1 row5" >Lightning, Etcher of the King</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row5_col0" class="data row5 col0" >8</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row5_col1" class="data row5 col1" >$33.84</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row6" class="row_heading level0 row6" >108</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row6" class="row_heading level1 row6" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row6_col0" class="data row6 col0" >9</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row6_col1" class="data row6 col1" >$31.77</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row7" class="row_heading level0 row7" >78</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row7" class="row_heading level1 row7" >Glimmer, Ender of the Moon</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row7_col1" class="data row7 col1" >$30.80</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row8" class="row_heading level0 row8" >72</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row8" class="row_heading level1 row8" >Winter's Bite</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row8_col1" class="data row8 col1" >$30.16</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row9" class="row_heading level0 row9" >60</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row9" class="row_heading level1 row9" >Wolf</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row9_col0" class="data row9 col0" >8</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row9_col1" class="data row9 col1" >$28.32</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row10" class="row_heading level0 row10" >179</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row10" class="row_heading level1 row10" >Wolf, Promise of the Moonwalker</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row10_col0" class="data row10 col0" >6</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row10_col1" class="data row10 col1" >$26.88</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row11" class="row_heading level0 row11" >160</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row11" class="row_heading level1 row11" >Azurewrath</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row11_col0" class="data row11 col0" >6</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row11_col1" class="data row11 col1" >$26.40</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row12" class="row_heading level0 row12" >25</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row12" class="row_heading level1 row12" >Hero Cane</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row12_col0" class="data row12 col0" >6</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row12_col1" class="data row12 col1" >$26.10</td>
#             </tr>
#             <tr>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level0_row13" class="row_heading level0 row13" >37</th>
#                         <th id="T_c191e8fe_c2da_11e9_b232_acde48001122level1_row13" class="row_heading level1 row13" >Shadow Strike, Glory of Ending Hope</th>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row13_col0" class="data row13 col0" >8</td>
#                         <td id="T_c191e8fe_c2da_11e9_b232_acde48001122row13_col1" class="data row13 col1" >$25.28</td>
#             </tr>
